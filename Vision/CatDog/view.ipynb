# %%
from IPython.display import display

# %%
from data import get_images, get_data

# %%
train_images, train_labels, test_images, test_labels = get_images()

# %% [markdown]
# 第一只测试集中的喵喵：

# %%
for image, label in zip(test_images, test_labels):
    if label == 0:
        display(image)
        break
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128 at 0x7F8318EB5BA8>

# %% [markdown]
# 第一只测试集中的汪汪：

# %%
for image, label in zip(test_images, test_labels):
    if label == 1:
        display(image)
        break
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128 at 0x7F8318EB5B38>

# %%
X_train, y_train, X_test, y_test = get_data(one_hot=True)

# %% [markdown]
# 训练集有20000张图片，每张大小128x128像素，每张图片有3个色彩通道（RGB，红绿蓝）
#
# 输出是2维的（onehot），也就是喵喵是[1, 0]，汪汪是[0, 1]

# %%
print(X_train.shape, y_train.shape)
# Out:
# (20000, 128, 128, 3) (20000, 2)

# %% [markdown]
# 测试集有5000张图片，每张大小128x128像素，每张图片有3个色彩通道（RGB，红绿蓝）

# %%
print(X_test.shape, y_test.shape)
# Out:
# (5000, 128, 128, 3) (5000, 2)
